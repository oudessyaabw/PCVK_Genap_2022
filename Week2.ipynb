# %% [markdown]
# <a href="https://colab.research.google.com/github/oudessyaabw/PCVK_Genap_2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PRAKTIKUM**
#
# 1. Buka https://colab.research.google.com/. Setelah dipastikan bahwa google Colab terhubung dengan Github Anda, lanjutkan dengan memilih repository yang telah digunakan pada praktikum minggu lalu, rename file menjadi “Week2.ipynb”.

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
import matplotlib.pylab as plt
import numpy as np

# %%
# Create display image screenshoot function
def display_image(url):
  img = io.imread(url)  
  img = cv.resize(img, (0,0), fx=0.5, fy=0.5)                           
  img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
  return cv2_imshow(img)

# %% [markdown]
# Kemudian import folder yang ada di Drive Anda dengan cara sebagai berikut.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Proses sinkronisasi google colab untuk terhubung dengan gdrive membutuhkan sedikit perubahan setting notifikasi seperti gambar berikut. Kemudian akan muncul suatu URL yang akan mengarah ke new tab untuk login akun google. Pada tahap ini dibutuhkan kode autorisasi yang muncul setelah proses login dilakukan. Setelah proses login dilakukan, maka salin kode autorisasi dan templkan pada field yang sudah disediakan pada google Colab.

# %% [markdown]
# Jika berhasil, maka Google Colab sudah dapat mengakses folder gdrive Anda dengan keterangan output program “Mounted at /content/drive”.

# %% [markdown]
# Kemudian kode program dapat dilanjutkan dengan membuka file Google Drive yang sudah ada. Contohnya pada kode program di bawah file image dengan nama kitten01.jpg akan dibuka untuk diproses lebih lanjut. Hasil nya berupa output gambar yang sudah di plot dengan matplotlib untuk mengetahui ukuran panjang dan lebar dari gambar tersebut.

# %%
image = cv.imread('/content/drive/MyDrive/PCVK/Image/Cat.JPG')
plt.imshow(image)

# %% [markdown]
# 2. OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red)
# Tampilkan nilai pixel dan image

# %%
image2 = image
image3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
plt.imshow(image3)

# %% [markdown]
# 3. Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan
#  citra hasil

# %%
image_gray = cv.imread('/content/drive/MyDrive/PCVK/Image/Cat.JPG', cv.IMREAD_GRAYSCALE)
plt.imshow(image_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray’

# %%
plt.imshow(image_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘magma’

# %%
plt.imshow(image_gray, cmap='magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
image_4 = cv.resize(cv.cvtColor(image, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(image_4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
image_5 = cv.flip(cv.cvtColor(image, cv.COLOR_BGR2RGB), 0)
plt.imshow(image_5)

# %% [markdown]
# 4. Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image
# dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
cv.rectangle(black_img, (384,0), (510,150), (0,255,0), 10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2
# yang tertulis pada kode program.

# %%
cv.rectangle(black_img, (200,200), (300,300), (0,0,255), 15)
plt.imshow(black_img)

# %% [markdown]
#  Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang
#  tertulis pada kode program.

# %%
cv.circle(black_img, (100,100), 50, (255,0,0), 8)
plt.imshow(black_img)

# %%
cv.circle(black_img, (400,400), 80, (255,0,0), -1)
plt.imshow(black_img)

# %% [markdown]
#  Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut

# %%
cv.line(black_img, (0,0), (512,512), (255,255,255), 5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah
# ditentukan

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, 'Hello', (10,500), font, 4, (255,255,0), 2, cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
#  Berikut adalah kode program untuk inisialisasi NumPy array dengan tpe data int32

# %%
vertices = np.array([
  [100,300],
  [200,200],
  [400,300],
  [200,400]                   
], np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
#  Penambahan polyline pada black image kedua yang telah dibuat.

# %%
cv.polylines(black_img2, [pts], True, (255,0,0),5)
plt.imshow(black_img2)

# %% [markdown]
# 5. Setelah semua kode selesai simpan “Week2.ipynb” pada GiHub Anda dengam memilih File kemudia “Save a copy in GitHub”.

# %% [markdown]
# # **Pertanyaan**
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
#   Jawab : Jika menggunakan matplotlib akan menampilkan juga ukuran pixel dari gambar tersebut
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
#
#   Jawab : Keduanya adalah integer (bilangan bulat) dengan perbedaan ada pada rentang nilai yang bisa ditampung. Bilangan bulat 32-bit artinya memiliki 2**32 (2 pangkat 32) nilai berbeda, atau dari -2.147.483.648 hingga 2.147.483.647. Sementara 64-bit memiliki 2**64 (2 pangkat 64) nilai berbeda atau -9.223.372.036.854.775.808 hingga 9.223.372.036.854.775.807.
#
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
#
#   Jawab: Fungsi reshape digunakan untuk membuat atau merubah baris kolom. Format penulisannya yaitu reshape([row], [column]) dimana row dan column berisi jumlah baris dan kolom yang diinginkan.
#
# 4. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut:
#
#   Jawab: library tersebut digunakan untuk menampilkan sebuah gambar pada openCV
#
# 5. Apakah kegunaan “skimage impot io” pada potongan kode soal nomor 4
#
#   Jawab: Library tersebut digunakan untuk untuk membaca dan menulis gambar dalam berbagai format

# %% [markdown]
# # **TUGAS**
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :
# 1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!
# 2. Tampilkan image baris ke 10-100, kolom 10-100!
# 3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja!
# 4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!
# 5. Tampilkan image dengan posisi terbalik!
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 6. Buat rectangle dan circle pada bagian wajah dari image kitten!
# 7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten01.jpg!

# %%
# 1. Tampilkan image dalam channel Red-Green dan Green-Blue saja!

image5 = cv.imread('/content/drive/MyDrive/PCVK/Image/Cat.JPG')
image6 = cv.cvtColor(image5, cv.COLOR_BGR2RGB)
R,G,B = cv.split(image6)
zeros = np.zeros(image6.shape[:2], dtype="uint8")
red_green = cv.merge([R,G,zeros])
plt.imshow(red_green)

# %%
green_blue = cv.merge([zeros,G,B])
plt.imshow(green_blue)

# %%
# 2. Tampilkan image baris ke 10-100, kolom 10-100!

image13 = cv.imread('/content/drive/MyDrive/PCVK/Image/Cat.JPG')
image14 = cv.cvtColor(image13, cv.COLOR_BGR2RGB)
crop = image14[10:100, 10:100]
plt.imshow(crop)

# %%
# 3. Tampilkan image baris ke 5-30, semua kolom, channel Green saja! 

green = cv.merge([zeros,G,zeros])
y=5
x=0
h=30
w=green.shape[1]
crop = green[y:h, x:w]
plt.imshow(crop)

# %%
# 4. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. disarankan menggunakan bilangan acak/random!

from random import randrange
image7 = cv.imread('/content/drive/MyDrive/PCVK/Image/Cat.JPG')
image8 = cv.cvtColor(image7, cv.COLOR_BGR2RGB)
tinggi = image8.shape[0]                            
lebar = image8.shape[1]  
for x in range(5):
  cv.rectangle(image8, (randrange(lebar),randrange(tinggi)), (randrange(lebar),randrange(tinggi)), (randrange(255),randrange(255),randrange(255)), 5)
plt.imshow(image8)

# %%
# 5. Tampilkan image dengan posisi terbalik!

image9 = cv.imread('/content/drive/MyDrive/PCVK/Image/Cat.JPG')
image10 = cv.flip(cv.cvtColor(image9, cv.COLOR_BGR2RGB), 0)
plt.imshow(image10)

# %%
# 6. Buat rectangle dan circle pada bagian wajah dari image kitten!
image11 = cv.imread('/content/drive/MyDrive/PCVK/Image/Cat.JPG')
image12 = cv.cvtColor(image11, cv.COLOR_BGR2RGB)
cv.circle(image12, (650,380), 180, (255,0,0), 5)
cv.rectangle(image12, (450,200), (850,570), (0,255,0), 10)
plt.imshow(image12)

# %%
# 7. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten01.jpg!
image19 = cv.imread('/content/drive/MyDrive/PCVK/Image/Cat.JPG')
image20 = cv.cvtColor(image19, cv.COLOR_BGR2RGB)
cv.rectangle(image20,pt1=(0,600), pt2=(400,image20.shape[1]), color=(255,255,255), thickness=8)
R,G,B = cv.split(image20)
zeros = np.zeros(image20.shape[:2], dtype="uint8")
blue = cv.merge([zeros,zeros,B])
plt.imshow(blue)
